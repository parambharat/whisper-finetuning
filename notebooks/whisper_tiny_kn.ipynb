# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/parambharat/malayalam_asr_corpus

# !add-apt-repository -y ppa:jonathonf/ffmpeg-4
# !apt update
# !apt install -y ffmpeg

# !pip uninstall -y transformers datasets 
# !pip install audiomentations
# !pip install git+https://github.com/huggingface/datasets
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa soundfile
# !pip install "evaluate>=0.3.0"
# !pip install jiwer
# !pip install more-itertools
# !pip install wandb
# !pip install bitsandbytes
# !pip install "bokeh<2.5"
# !pip install "holoviews[recommended]"

# %%
# %set_env WANDB_LOG_MODEL=True
# %set_env WANDB_WATCH=all
# %set_env WANDB_NOTEBOOK_NAME=whisper_tiny_kn.ipynb
# Out:
# env: WANDB_LOG_MODEL=True
# env: WANDB_WATCH=all
# env: WANDB_NOTEBOOK_NAME=whisper_tiny_kn.ipynb

# %%
from datasets import Dataset, IterableDatasetDict, load_dataset, interleave_datasets, Audio 
import evaluate

import torch
import string
from dataclasses import dataclass
from typing import Any, Dict, List, Union

from transformers import WhisperForConditionalGeneration
from transformers import WhisperProcessor
from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer
from transformers import WhisperTokenizer
from transformers import WhisperFeatureExtractor
import wandb
from IPython.display import clear_output
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np
from huggingface_hub import notebook_login
from transformers import TrainerCallback
from transformers.integrations import WandbCallback
from transformers.trainer_pt_utils import IterableDatasetShard
from torch.utils.data import IterableDataset
from datasets import load_dataset, Audio
from pathlib import Path
import numpy as np
import holoviews as hv
import panel as pn
import tempfile
from bokeh.resources import INLINE
hv.extension("bokeh", logo=False)

from io import StringIO
import pandas as pd
import warnings
import jiwer
warnings.filterwarnings('ignore')

clear_output()
torch.cuda.is_available()
# Out:
# True

# %%
run = wandb.init(project="whisper_finetuning", job_type="fine-tuning", group="tiny-kn",)
# Out:
# wandb: Currently logged in as: parambharat. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/root/Documents/whisper-finetuning/notebooks/wandb/run-20221214_044009-10ccca1i</code>
# Syncing run <strong><a href="https://wandb.ai/parambharat/whisper_finetuning/runs/10ccca1i" target="_blank">elated-haze-83</a></strong> to <a href="https://wandb.ai/parambharat/whisper_finetuning" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# artifact = run.use_artifact('parambharat/whisper_finetuning/model-13kya0x9:latest', type='model')
# artifact_dir = artifact.download()

# %%
def load_data_splits(is_streaming=True, stopping_strategy="all_exhausted"):
    dataset_dict = {}
    
    dataset_dict["train"] = load_dataset("../data/kannada_asr_corpus/", split="train", streaming=is_streaming)
    dataset_dict["test"] = load_dataset("google/fleurs", "kn_in", split="test", streaming=True)
    dataset_dict["test"] = dataset_dict["test"].rename_column("transcription", "sentence")
    dataset_dict["test"] = dataset_dict["test"].remove_columns(
        [col for col in dataset_dict["test"].features.keys() if col not in ["audio", "sentence"]])
    dataset_dict["test"] = dataset_dict["test"].cast_column("audio", Audio(sampling_rate=16000))
    return dataset_dict

# %%
dataset_dict = load_data_splits()

# %%
augment_waveform = Compose([
    AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.015, p=0.3),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.3, leave_length_unchanged=False),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.3)
    ,])

def augment_dataset(batch):

    audio = batch["audio"]["array"]
    # apply augmentation
    augmented_audio = augment_waveform(samples=audio, sample_rate=16000)

    batch["audio"]["array"] = augmented_audio

    return batch


# call augment dataset on the training set
dataset_dict["train"] = dataset_dict["train"].map(augment_dataset)

# %%
feature_extractor = WhisperFeatureExtractor.from_pretrained(
    "openai/whisper-tiny"
)
tokenizer = WhisperTokenizer.from_pretrained(
    "openai/whisper-tiny", 
     language="Kannada",
     task="transcribe",
     model_max_length=225
)
processor = WhisperProcessor.from_pretrained(
    "openai/whisper-tiny",
     language="Kannada", 
     task="transcribe",
     model_max_length=225
)

# %%
def fix_sentence(sentence):
    transcription = sentence
  
    if transcription.startswith('"') and transcription.endswith('"'):
        # we can remove trailing quotation marks as they do not affect the transcription
        transcription = transcription[1:-1]
  
    if transcription[-1] not in [".", "?", "!"]:
        # append a full-stop to sentences that do not end in punctuation
        transcription = transcription + "."
    transcription = transcription[:-1].translate(str.maketrans('', '', string.punctuation)) + transcription[-1]
    return transcription
    
def prepare_dataset(examples):
    # compute log-Mel input features from input audio array 
    audio = examples["audio"]
    
    examples["input_features"] = feature_extractor(
        audio["array"], sampling_rate=16000).input_features[0]
    
    sentences = fix_sentence(examples["sentence"])
    
    # encode target text to label ids 
    examples["labels"] = tokenizer(sentences, max_length=225, truncation=True).input_ids
    return examples

# %%
def filter_empty_strings(sentence):
    if len(sentence) < 2:
        return False
    else: return True

# %%
for k in dataset_dict:
    dataset_dict[k] = dataset_dict[k].filter(filter_empty_strings, input_columns=["sentence"])

# %%
for k in dataset_dict:
    dataset_dict[k] = dataset_dict[k].map(
        prepare_dataset,).with_format("torch")

# %%
dataset_dict["train"] = dataset_dict["train"].shuffle(buffer_size=500)

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": self.processor.tokenizer.truncate_sequences(feature["labels"])[0]}
                          for feature in features]
        # pad the labels to max length
        
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt",)

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
metric = evaluate.load("wer")

# evaluate with the 'normalised' WER
do_normalize_eval = True


def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = processor.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, normalize=do_normalize_eval)
    label_str = processor.tokenizer.batch_decode(label_ids, skip_special_tokens=True, normalize=do_normalize_eval)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-tiny", use_cache=False)
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []
model.config.use_cache = False

# %%
# trainer callback to reinitialise and reshuffle the streamable datasets at the beginning of each epoch
class ShuffleCallback(TrainerCallback):
    def on_epoch_begin(self, args, state, control, train_dataloader, **kwargs):
        if isinstance(train_dataloader.dataset, IterableDatasetShard):
            pass  # set_epoch() is handled by the Trainer
        elif isinstance(train_dataloader.dataset, IterableDataset):
            train_dataloader.dataset.set_epoch(train_dataloader.dataset._epoch + 1)

# %%
def load_samples_dataset(dataset, num_samples=100):
    samples = []
    for i, item in enumerate(dataset):
        samples.append(item)
        if i == (num_samples-1):
            break
    sample_dataset = Dataset.from_list(samples)
    return sample_dataset

def compute_spectrograms(example):
    waveform =  example["audio"]["array"]
    specs = feature_extractor(waveform, sampling_rate=16000, padding="do_not_pad").input_features[0]
    return {"spectrogram": specs}


def record_to_html(sample_record):
    audio_array = np.array(sample_record["audio"]["array"])
    audio_sr = sample_record["audio"]["sampling_rate"]
    length = sample_record.get("length")
    if length:
        audio_duration = length
    else:
        sample_record["length"] = audio_duration = len(audio_array)/audio_sr
    audio_duration = sample_record["length"]
    audio_spectrogram = np.array(sample_record["spectrogram"])

    bounds = (0,0, audio_duration, audio_spectrogram.max())

    waveform_int = np.int16(audio_array * 32767)

    
    
    hv_audio = pn.pane.Audio(waveform_int, sample_rate=audio_sr, name='Audio', throttle=500)
    
    slider = pn.widgets.FloatSlider(end=audio_duration, visible=False, step=0.001)
    line_audio = hv.VLine(0).opts(color='black')
    line_spec = hv.VLine(0).opts(color='red')
    
    
    slider.jslink(hv_audio, value='time', bidirectional=True)
    slider.jslink(line_audio, value='glyph.location')
    slider.jslink(line_spec, value='glyph.location')
    
    time = np.linspace(0, audio_duration, num=len(audio_array))
    line_plot_hv = hv.Curve(
        (time, audio_array), ["Time (s)", "amplitude"]).opts(
        width=500, height=150, axiswise=True) * line_audio
    
    hv_spec_gram = hv.Image(
        audio_spectrogram, bounds=(bounds), kdims=["Time (s)", "Frequency (hz)"]).opts(
        width=500, height=150, labelled=[], axiswise=True, color_levels=512)* line_spec
    
    
    combined = pn.Row(hv_audio, hv_spec_gram, line_plot_hv, slider)
    audio_html = StringIO()
    combined.save(audio_html)
    sample_record["audio_with_spec"] = audio_html
    return sample_record


def dataset_to_records(dataset):
    records = []
    for item in dataset:
        record = {}
        sample_record = record_to_html(item)
        record["audio_with_spec"] = wandb.Html(sample_record["audio_with_spec"])
        record["sentence"] = sample_record["sentence"]
        record["length"] =  sample_record["length"]
        records.append(record)
    records = pd.DataFrame(records)
    return records
    
def decode_predictions(trainer, predictions):
    pred_ids = predictions.predictions
    pred_str = trainer.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, )
    return pred_str


def compute_measures(predictions, labels):
    measures = [jiwer.compute_measures(ls, ps) for ps, ls in zip(predictions, labels)]
    measures_df = pd.DataFrame(measures)[["wer", "hits", "substitutions", "deletions", "insertions"]]
    return measures_df

class WandbProgressResultsCallback(WandbCallback):
    def __init__(self, trainer, sample_dataset): 
        super().__init__()
        self.trainer = trainer
        self.sample_dataset = sample_dataset
        self.records_df = dataset_to_records(sample_dataset)
        
    def on_log(self, args, state, control, model=None, logs=None, **kwargs):
        super().on_log(args, state, control, model, logs)
        predictions = trainer.predict(self.sample_dataset)
        predictions = decode_predictions(self.trainer, predictions)
        measures_df = compute_measures(predictions, self.records_df["sentence"].tolist())
        records_df = pd.concat([self.records_df, measures_df], axis=1)
        records_df["prediction"] = predictions
        records_df["step"] = state.global_step
        records_table = self._wandb.Table(dataframe=records_df)
        self._wandb.log({"sample_predictions": records_table})
        
    def on_save(self, args, state, control, model=None, tokenizer=None, **kwargs):
        if self._wandb is None:
            return
        if self._log_model and self._initialized and state.is_world_process_zero:
            with tempfile.TemporaryDirectory() as temp_dir:

                self.trainer.save_model(temp_dir)
                metadata = (
                    {
                        k: v
                        for k, v in dict(self._wandb.summary).items()
                        if isinstance(v, numbers.Number) and not k.startswith("_")
                    }
                    if not args.load_best_model_at_end
                    else {
                        f"eval/{args.metric_for_best_model}": state.best_metric,
                        "train/total_floss": state.total_flos,
                    }
                )
                artifact = self._wandb.Artifact(
                    name=f"model-{self._wandb.run.id}",
                    type="model", metadata=metadata)
                for f in Path(temp_dir).glob("*"):
                    if f.is_file():
                        with artifact.new_file(f.name, mode="wb") as fa:
                            fa.write(f.read_bytes())
                self._wandb.run.log_artifact(artifact)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="../models/whisper-tiny-kn",  # change to a repo name of your choice
    per_device_train_batch_size=150,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    save_total_limit=4,
    warmup_steps=500,
    max_steps=3000,
    gradient_checkpointing=True,
    fp16=True,
#     fp16_full_eval=True,
    optim="adamw_bnb_8bit",
    evaluation_strategy="steps",
    per_device_eval_batch_size=64,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=300,
    eval_steps=300,
    logging_steps=100,
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    hub_strategy="checkpoint",
    push_to_hub=True,
    remove_unused_columns=False, 
    ignore_data_skip=True
)

# %%
samples_dataset = load_samples_dataset(dataset_dict["test"]).map(compute_spectrograms)
# Out:
#   0%|          | 0/100 [00:00<?, ?ex/s]

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=dataset_dict["train"],
    eval_dataset=samples_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor,
    callbacks=[ShuffleCallback(), ],
    
)
# Out:
# /root/Documents/whisper-finetuning/notebooks/../models/whisper-tiny-kn is already a clone of https://huggingface.co/parambharat/whisper-tiny-kn. Make sure you pull the latest changes with `repo.git_pull()`.
# max_steps is given, it will override any value given in num_train_epochs
# Using cuda_amp half precision backend

# %%
progress_callback = WandbProgressResultsCallback(trainer, samples_dataset)
clear_output()

# %%
trainer.add_callback(progress_callback)

# %%
model.save_pretrained(training_args.output_dir)
processor.save_pretrained(training_args.output_dir)
# Out:
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 450000
#   Num Epochs = 9223372036854775807
#   Instantaneous batch size per device = 150
#   Total train batch size (w. parallel, distributed & accumulation) = 150
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3000
#   Number of trainable parameters = 37760640
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='3000' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3000/3000 16:09:57, Epoch 2/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>1.409100</td>
#       <td>1.491542</td>
#       <td>101.502630</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.129400</td>
#       <td>1.284546</td>
#       <td>94.740796</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.542600</td>
#       <td>0.462114</td>
#       <td>64.237415</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.412800</td>
#       <td>0.369490</td>
#       <td>54.658152</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.362900</td>
#       <td>0.341448</td>
#       <td>52.967693</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.332100</td>
#       <td>0.324948</td>
#       <td>50.300526</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.306600</td>
#       <td>0.318106</td>
#       <td>48.910594</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.295800</td>
#       <td>0.313574</td>
#       <td>47.783621</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.288300</td>
#       <td>0.305534</td>
#       <td>46.619083</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.285700</td>
#       <td>0.305707</td>
#       <td>46.393689</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:17]
#     </div>
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-300
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-300/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-300/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-300/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-300/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-300/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Saving model checkpoint to /tmp/tmps3z76fes
# Configuration saved in /tmp/tmps3z76fes/config.json
# Model weights saved in /tmp/tmps3z76fes/pytorch_model.bin
# Feature extractor saved in /tmp/tmps3z76fes/preprocessor_config.json
# tokenizer config file saved in /tmp/tmps3z76fes/tokenizer_config.json
# Special tokens file saved in /tmp/tmps3z76fes/special_tokens_map.json
# added tokens file saved in /tmp/tmps3z76fes/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    34f1a48..fac29a9  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    fac29a9..9310585  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-600
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-600/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-600/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-600/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-600/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-600/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-600/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Saving model checkpoint to /tmp/tmpw0btz0r4
# Configuration saved in /tmp/tmpw0btz0r4/config.json
# Model weights saved in /tmp/tmpw0btz0r4/pytorch_model.bin
# Feature extractor saved in /tmp/tmpw0btz0r4/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpw0btz0r4/tokenizer_config.json
# Special tokens file saved in /tmp/tmpw0btz0r4/special_tokens_map.json
# added tokens file saved in /tmp/tmpw0btz0r4/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    9310585..af13578  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    af13578..b59cea9  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-900
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-900/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-900/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-900/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-900/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-900/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-900/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Saving model checkpoint to /tmp/tmp8hqs3xxf
# Configuration saved in /tmp/tmp8hqs3xxf/config.json
# Model weights saved in /tmp/tmp8hqs3xxf/pytorch_model.bin
# Feature extractor saved in /tmp/tmp8hqs3xxf/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp8hqs3xxf/tokenizer_config.json
# Special tokens file saved in /tmp/tmp8hqs3xxf/special_tokens_map.json
# added tokens file saved in /tmp/tmp8hqs3xxf/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    b59cea9..159b4fb  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    159b4fb..59227ef  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-1200
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-1200/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-1200/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-1200/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-1200/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-1200/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Saving model checkpoint to /tmp/tmpqzaw8xe7
# Configuration saved in /tmp/tmpqzaw8xe7/config.json
# Model weights saved in /tmp/tmpqzaw8xe7/pytorch_model.bin
# Feature extractor saved in /tmp/tmpqzaw8xe7/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpqzaw8xe7/tokenizer_config.json
# Special tokens file saved in /tmp/tmpqzaw8xe7/special_tokens_map.json
# added tokens file saved in /tmp/tmpqzaw8xe7/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    59227ef..03ef932  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    03ef932..6ec55d3  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-1500
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-1500/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-1500/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-1500/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-1500/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-300] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpecmwz3n5
# Configuration saved in /tmp/tmpecmwz3n5/config.json
# Model weights saved in /tmp/tmpecmwz3n5/pytorch_model.bin
# Feature extractor saved in /tmp/tmpecmwz3n5/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpecmwz3n5/tokenizer_config.json
# Special tokens file saved in /tmp/tmpecmwz3n5/special_tokens_map.json
# added tokens file saved in /tmp/tmpecmwz3n5/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    6ec55d3..261ffc2  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    261ffc2..861b15d  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-1800
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-1800/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-1800/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-1800/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-1800/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-600] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpnv3yy8nu
# Configuration saved in /tmp/tmpnv3yy8nu/config.json
# Model weights saved in /tmp/tmpnv3yy8nu/pytorch_model.bin
# Feature extractor saved in /tmp/tmpnv3yy8nu/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpnv3yy8nu/tokenizer_config.json
# Special tokens file saved in /tmp/tmpnv3yy8nu/special_tokens_map.json
# added tokens file saved in /tmp/tmpnv3yy8nu/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    861b15d..ad12cda  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    ad12cda..e966f83  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-2100
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-2100/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-2100/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-2100/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-2100/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-2100/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-2100/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-900] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpinl4i74b
# Configuration saved in /tmp/tmpinl4i74b/config.json
# Model weights saved in /tmp/tmpinl4i74b/pytorch_model.bin
# Feature extractor saved in /tmp/tmpinl4i74b/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpinl4i74b/tokenizer_config.json
# Special tokens file saved in /tmp/tmpinl4i74b/special_tokens_map.json
# added tokens file saved in /tmp/tmpinl4i74b/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    e966f83..33a2f4f  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    33a2f4f..6ae060f  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-2400
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-2400/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-2400/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-2400/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-2400/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-1200] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmp_uiq08_t
# Configuration saved in /tmp/tmp_uiq08_t/config.json
# Model weights saved in /tmp/tmp_uiq08_t/pytorch_model.bin
# Feature extractor saved in /tmp/tmp_uiq08_t/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp_uiq08_t/tokenizer_config.json
# Special tokens file saved in /tmp/tmp_uiq08_t/special_tokens_map.json
# added tokens file saved in /tmp/tmp_uiq08_t/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    6ae060f..17f5ebf  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    17f5ebf..bfea505  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-2700
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-2700/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-2700/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-2700/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-2700/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-2700/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-2700/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpbodpm9_y
# Configuration saved in /tmp/tmpbodpm9_y/config.json
# Model weights saved in /tmp/tmpbodpm9_y/pytorch_model.bin
# Feature extractor saved in /tmp/tmpbodpm9_y/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpbodpm9_y/tokenizer_config.json
# Special tokens file saved in /tmp/tmpbodpm9_y/special_tokens_map.json
# added tokens file saved in /tmp/tmpbodpm9_y/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    bfea505..70ba83f  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    70ba83f..cd1ac10  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 64
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# Saving model checkpoint to ../models/whisper-tiny-kn/checkpoint-3000
# Configuration saved in ../models/whisper-tiny-kn/checkpoint-3000/config.json
# Model weights saved in ../models/whisper-tiny-kn/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/checkpoint-3000/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/checkpoint-3000/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/checkpoint-3000/added_tokens.json
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Deleting older checkpoint [../models/whisper-tiny-kn/checkpoint-1800] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpo645z4um
# Configuration saved in /tmp/tmpo645z4um/config.json
# Model weights saved in /tmp/tmpo645z4um/pytorch_model.bin
# Feature extractor saved in /tmp/tmpo645z4um/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpo645z4um/tokenizer_config.json
# Special tokens file saved in /tmp/tmpo645z4um/special_tokens_map.json
# added tokens file saved in /tmp/tmpo645z4um/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file last-checkpoint/optimizer.pt:   0%|          | 32.0k/191M [00:00<?, ?B/s]
# Upload file pytorch_model.bin:   0%|          | 32.0k/144M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    cd1ac10..f935f4c  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    f935f4c..13ce05c  main -> main
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/whisper-tiny-kn/checkpoint-3000 (score: 46.393688955672424).
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 64
# /root/Documents/whisper-finetuning/notebooks/../models/whisper-tiny-kn is already a clone of https://huggingface.co/parambharat/whisper-tiny-kn. Make sure you pull the latest changes with `repo.git_pull()`.
# max_steps is given, it will override any value given in num_train_epochs
# Using cuda_amp half precision backend
# Saving model checkpoint to /tmp/tmpla5lbty6
# Configuration saved in /tmp/tmpla5lbty6/config.json
# Model weights saved in /tmp/tmpla5lbty6/pytorch_model.bin
# Feature extractor saved in /tmp/tmpla5lbty6/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpla5lbty6/tokenizer_config.json
# Special tokens file saved in /tmp/tmpla5lbty6/special_tokens_map.json
# added tokens file saved in /tmp/tmpla5lbty6/added_tokens.json
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    13ce05c..e42d6bd  main -> main
# TrainOutput(global_step=3000, training_loss=0.6097468535105387, metrics={'train_runtime': 58214.4314, 'train_samples_per_second': 7.73, 'train_steps_per_second': 0.052, 'total_flos': 1.107519937339392e+19, 'train_loss': 0.6097468535105387, 'epoch': 2.23})

# %%
kwargs = {
    "language": "kn",
    "model_name": "Whisper Tiny Kn - Bharat Ramanathan",  # a 'pretty' name for your model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
    "tags": "whisper-event",
}

# %%
trainer.push_to_hub(**kwargs)
# Out:
# Saving model checkpoint to ../models/whisper-tiny-kn
# Configuration saved in ../models/whisper-tiny-kn/config.json
# Model weights saved in ../models/whisper-tiny-kn/pytorch_model.bin
# Feature extractor saved in ../models/whisper-tiny-kn/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-tiny-kn/tokenizer_config.json
# Special tokens file saved in ../models/whisper-tiny-kn/special_tokens_map.json
# added tokens file saved in ../models/whisper-tiny-kn/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}, 'metrics': [{'name': 'Wer', 'type': 'wer', 'value': 46.393688955672424}]}
# To https://huggingface.co/parambharat/whisper-tiny-kn
#    e42d6bd..3057a51  main -> main

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2062.341 MB of 2062.341 MB uploaded (611.903 MB deduped)\r'), FloatProgress(value=…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▇▂▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>█▁▁▂▂▁▁▁▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▁██▇▇█████</td></tr><tr><td>eval/steps_per_second</td><td>▁█████████</td></tr><tr><td>eval/wer</td><td>█▇▃▂▂▁▁▁▁▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▇▇▇███████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>train/learning_rate</td><td>▂▄▅▇██▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▂▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>█▅▅▄▄▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.30571</td></tr><tr><td>eval/runtime</td><td>51.0651</td></tr><tr><td>eval/samples_per_second</td><td>1.958</td></tr><tr><td>eval/steps_per_second</td><td>0.039</td></tr><tr><td>eval/wer</td><td>46.39369</td></tr><tr><td>train/epoch</td><td>2.23</td></tr><tr><td>train/global_step</td><td>3000</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.2857</td></tr><tr><td>train/total_flos</td><td>1.107519937339392e+19</td></tr><tr><td>train/train_loss</td><td>0.60975</td></tr><tr><td>train/train_runtime</td><td>58214.4314</td></tr><tr><td>train/train_samples_per_second</td><td>7.73</td></tr><tr><td>train/train_steps_per_second</td><td>0.052</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">elated-haze-83</strong>: <a href="https://wandb.ai/parambharat/whisper_finetuning/runs/10ccca1i" target="_blank">https://wandb.ai/parambharat/whisper_finetuning/runs/10ccca1i</a><br/>Synced 6 W&B file(s), 41 media file(s), 149 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221214_044009-10ccca1i/logs</code>
