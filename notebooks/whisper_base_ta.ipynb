# %%
# !pip uninstall -y transformers datasets 
# !pip install audiomentations
# !pip install git+https://github.com/huggingface/datasets
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa soundfile
# !pip install "evaluate>=0.3.0"
# !pip install jiwer
# !pip install gradio
# !pip install more-itertools
# !pip install wandb
# !pip install bitsandbytes
# !pip install "bokeh<2.5.0"
# !pip install "holoviews[recommended]"
# !pip install pandas

# %%
# %set_env WANDB_LOG_MODEL=True
# %set_env WANDB_WATCH=all
# %set_env WANDB_NOTEBOOK_NAME=whisper_base_ta.ipynb
# Out:
# env: WANDB_LOG_MODEL=True
# env: WANDB_WATCH=all
# env: WANDB_NOTEBOOK_NAME=whisper_base_ta.ipynb

# %%
from datasets import Dataset, IterableDatasetDict, load_dataset, interleave_datasets, Audio 
import evaluate

import torch
import string
from dataclasses import dataclass
from typing import Any, Dict, List, Union

from transformers import WhisperForConditionalGeneration
from transformers import WhisperProcessor
from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer
from transformers import WhisperTokenizer
from transformers import WhisperFeatureExtractor
import wandb
from IPython.display import clear_output
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np
from huggingface_hub import notebook_login
from transformers import TrainerCallback
from transformers.integrations import WandbCallback
from transformers.trainer_pt_utils import IterableDatasetShard
from torch.utils.data import IterableDataset
from datasets import load_dataset, Audio
from pathlib import Path
import numpy as np
import holoviews as hv
import panel as pn
import tempfile
from bokeh.resources import INLINE
hv.extension("bokeh", logo=False)

from io import StringIO
import pandas as pd
import warnings
import jiwer
warnings.filterwarnings('ignore')

clear_output()
torch.cuda.is_available()

# %%
# wandb.login()
# notebook_login()

# %%
run = wandb.init(project="whisper_finetuning", job_type="fine-tuning", group="base", resume="must", id="20dsv01o")

# %%
def load_data_splits(is_streaming=True, stopping_strategy="all_exhausted"):
    dataset_dict = {}
    
    data_dict = load_dataset("../data/tamil_asr_corpus/", streaming=is_streaming)
        
    return data_dict

# %%
dataset_dict = load_data_splits()

# %%
augment_waveform = Compose([
    AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.015, p=0.3),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.3, leave_length_unchanged=False),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.3)
    ,])

def augment_dataset(batch):

    audio = batch["audio"]["array"]
    # apply augmentation
    augmented_audio = augment_waveform(samples=audio, sample_rate=16000)

    batch["audio"]["array"] = augmented_audio

    return batch


# call augment dataset on the training set
dataset_dict["train"] = dataset_dict["train"].map(augment_dataset)

# %%
feature_extractor = WhisperFeatureExtractor.from_pretrained(
    "openai/whisper-base"
)
tokenizer = WhisperTokenizer.from_pretrained(
    "openai/whisper-base", 
     language="Tamil",
     task="transcribe",
     model_max_length=225
)
processor = WhisperProcessor.from_pretrained(
    "openai/whisper-base",
     language="Tamil", 
     task="transcribe",
     model_max_length=225
)

# %%
def fix_sentence(sentence):
    transcription = sentence
  
    if transcription.startswith('"') and transcription.endswith('"'):
        # we can remove trailing quotation marks as they do not affect the transcription
        transcription = transcription[1:-1]
  
    if transcription[-1] not in [".", "?", "!"]:
        # append a full-stop to sentences that do not end in punctuation
        transcription = transcription + "."
    transcription = transcription[:-1].translate(str.maketrans('', '', string.punctuation)) + transcription[-1]
    return transcription
    
def prepare_dataset(examples):
    # compute log-Mel input features from input audio array 
    audio = examples["audio"]
    
    examples["input_features"] = feature_extractor(
        audio["array"], sampling_rate=16000).input_features[0]
    
    sentences = fix_sentence(examples["sentence"])
    
    # encode target text to label ids 
    examples["labels"] = tokenizer(sentences, max_length=225, truncation=True).input_ids
    return examples

# %%
def filter_empty_strings(sentence):
    if len(sentence) < 2:
        return False
    else: return True

# %%
for k in dataset_dict:
    dataset_dict[k] = dataset_dict[k].filter(filter_empty_strings, input_columns=["sentence"])

# %%
for k in dataset_dict:
    dataset_dict[k] = dataset_dict[k].map(
        prepare_dataset,).with_format("torch")

# %%
dataset_dict["train"] = dataset_dict["train"].shuffle(buffer_size=500)

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": self.processor.tokenizer.truncate_sequences(feature["labels"])[0]}
                          for feature in features]
        # pad the labels to max length
        
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt",)

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
metric = evaluate.load("wer")

# evaluate with the 'normalised' WER
do_normalize_eval = True


def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = processor.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, normalize=do_normalize_eval)
    label_str = processor.tokenizer.batch_decode(label_ids, skip_special_tokens=True, normalize=do_normalize_eval)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-base", use_cache=False)
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []
model.config.use_cache = False

# %%
# trainer callback to reinitialise and reshuffle the streamable datasets at the beginning of each epoch
class ShuffleCallback(TrainerCallback):
    def on_epoch_begin(self, args, state, control, train_dataloader, **kwargs):
        if isinstance(train_dataloader.dataset, IterableDatasetShard):
            pass  # set_epoch() is handled by the Trainer
        elif isinstance(train_dataloader.dataset, IterableDataset):
            train_dataloader.dataset.set_epoch(train_dataloader.dataset._epoch + 1)

# %%
def load_samples_dataset(dataset, num_samples=100):
    samples = []
    for i, item in enumerate(dataset):
        samples.append(item)
        if i == (num_samples-1):
            break
    sample_dataset = Dataset.from_list(samples)
    return sample_dataset

def compute_spectrograms(example):
    waveform =  example["audio"]["array"]
    specs = feature_extractor(waveform, sampling_rate=16000, padding="do_not_pad").input_features[0]
    return {"spectrogram": specs}


def record_to_html(sample_record):
    audio_array = np.array(sample_record["audio"]["array"])
    audio_sr = sample_record["audio"]["sampling_rate"]
    audio_duration = sample_record["length"]
    audio_spectrogram = np.array(sample_record["spectrogram"])

    bounds = (0,0, audio_duration, audio_spectrogram.max())

    waveform_int = np.int16(audio_array * 32767)

    
    
    hv_audio = pn.pane.Audio(waveform_int, sample_rate=audio_sr, name='Audio', throttle=500)
    
    slider = pn.widgets.FloatSlider(end=audio_duration, visible=False, step=0.001)
    line_audio = hv.VLine(0).opts(color='black')
    line_spec = hv.VLine(0).opts(color='red')
    
    
    slider.jslink(hv_audio, value='time', bidirectional=True)
    slider.jslink(line_audio, value='glyph.location')
    slider.jslink(line_spec, value='glyph.location')
    
    time = np.linspace(0, audio_duration, num=len(audio_array))
    line_plot_hv = hv.Curve(
        (time, audio_array), ["Time (s)", "amplitude"]).opts(
        width=500, height=150, axiswise=True) * line_audio
    
    hv_spec_gram = hv.Image(
        audio_spectrogram, bounds=(bounds), kdims=["Time (s)", "Frequency (hz)"]).opts(
        width=500, height=150, labelled=[], axiswise=True, color_levels=512)* line_spec
    
    
    combined = pn.Row(hv_audio, hv_spec_gram, line_plot_hv, slider)
    audio_html = StringIO()
    combined.save(audio_html)
    return audio_html


def dataset_to_records(dataset):
    records = []
    for item in dataset:
        record = {}
        record["audio_with_spec"] = wandb.Html(record_to_html(item))
        record["sentence"] = item["sentence"]
        record["length"] = item["length"]
        records.append(record)
    records = pd.DataFrame(records)
    return records
    
def decode_predictions(trainer, predictions):
    pred_ids = predictions.predictions
    pred_str = trainer.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, )
    return pred_str


def compute_measures(predictions, labels):
    measures = [jiwer.compute_measures(ls, ps) for ps, ls in zip(predictions, labels)]
    measures_df = pd.DataFrame(measures)[["wer", "hits", "substitutions", "deletions", "insertions"]]
    return measures_df

class WandbProgressResultsCallback(WandbCallback):
    def __init__(self, trainer, sample_dataset): 
        super().__init__()
        self.trainer = trainer
        self.sample_dataset = sample_dataset
        self.records_df = dataset_to_records(sample_dataset)
        
    def on_log(self, args, state, control, model=None, logs=None, **kwargs):
        super().on_log(args, state, control, model, logs)
        predictions = trainer.predict(self.sample_dataset)
        predictions = decode_predictions(self.trainer, predictions)
        measures_df = compute_measures(predictions, self.records_df["sentence"].tolist())
        records_df = pd.concat([self.records_df, measures_df], axis=1)
        records_df["prediction"] = predictions
        records_df["step"] = state.global_step
        records_table = self._wandb.Table(dataframe=records_df)
        self._wandb.log({"sample_predictions": records_table})
        
    def on_save(self, args, state, control, model=None, tokenizer=None, **kwargs):
        if self._wandb is None:
            return
        if self._log_model and self._initialized and state.is_world_process_zero:
            with tempfile.TemporaryDirectory() as temp_dir:
                self.trainer.save_model(temp_dir)
                metadata = (
                    {
                        k: v
                        for k, v in dict(self._wandb.summary).items()
                        if isinstance(v, numbers.Number) and not k.startswith("_")
                    }
                    if not args.load_best_model_at_end
                    else {
                        f"eval/{args.metric_for_best_model}": state.best_metric,
                        "train/total_floss": state.total_flos,
                    }
                )
                artifact = self._wandb.Artifact(
                    name=f"model-{self._wandb.run.id}",
                    type="model", metadata=metadata)
                for f in Path(temp_dir).glob("*"):
                    if f.is_file():
                        with artifact.new_file(f.name, mode="wb") as fa:
                            fa.write(f.read_bytes())
                self._wandb.run.log_artifact(artifact)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="../models/whisper-base-ta",  # change to a repo name of your choice
    per_device_train_batch_size=64,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    save_total_limit=4,
    warmup_steps=500,
    max_steps=10000,
    gradient_checkpointing=True,
    fp16=True,
#     fp16_full_eval=True,
    optim="adamw_bnb_8bit",
    evaluation_strategy="steps",
    per_device_eval_batch_size=32,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=250,
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    hub_strategy="checkpoint",
    remove_unused_columns=False, 
    ignore_data_skip=True
)

# %%
samples_dataset = load_samples_dataset(dataset_dict["test"]).map(compute_spectrograms)

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=dataset_dict["train"],
    eval_dataset=samples_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor,
    callbacks=[ShuffleCallback()],
    
)

# %%
progress_callback = WandbProgressResultsCallback(trainer, samples_dataset)
clear_output()

# %%
trainer.add_callback(progress_callback)

# %%
# model.save_pretrained(training_args.output_dir)
# processor.save_pretrained(training_args.output_dir)

# %%
trainer.train(resume_from_checkpoint=True)
# Out:
# Loading model from ../models/whisper-base-ta/checkpoint-6000.
# ***** Running training *****
#   Num examples = 640000
#   Num Epochs = 9223372036854775807
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10000
#   Number of trainable parameters = 72593920
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 0
#   Continuing training from global step 6000
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 13:25:15, Epoch 0/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>6500</td>
#       <td>0.242100</td>
#       <td>0.241099</td>
#       <td>23.039454</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.242500</td>
#       <td>0.236957</td>
#       <td>23.380419</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.240400</td>
#       <td>0.233305</td>
#       <td>22.795908</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.238100</td>
#       <td>0.231064</td>
#       <td>22.942036</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.242900</td>
#       <td>0.230466</td>
#       <td>22.016561</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.240200</td>
#       <td>0.228417</td>
#       <td>22.113980</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.237700</td>
#       <td>0.227098</td>
#       <td>22.065270</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.238900</td>
#       <td>0.226931</td>
#       <td>21.724306</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='4' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/4 00:23]
#     </div>
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-6500
# Configuration saved in ../models/whisper-base-ta/checkpoint-6500/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-6500/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-6500/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-6500/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-6500/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Saving model checkpoint to /tmp/tmp2qjm4fnl
# Configuration saved in /tmp/tmp2qjm4fnl/config.json
# Model weights saved in /tmp/tmp2qjm4fnl/pytorch_model.bin
# Feature extractor saved in /tmp/tmp2qjm4fnl/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp2qjm4fnl/tokenizer_config.json
# Special tokens file saved in /tmp/tmp2qjm4fnl/special_tokens_map.json
# added tokens file saved in /tmp/tmp2qjm4fnl/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    835c8d0..3d926ba  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-7000
# Configuration saved in ../models/whisper-base-ta/checkpoint-7000/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-7000/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-7000/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-7000/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-7000/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Saving model checkpoint to /tmp/tmpq_x39etg
# Configuration saved in /tmp/tmpq_x39etg/config.json
# Model weights saved in /tmp/tmpq_x39etg/pytorch_model.bin
# Feature extractor saved in /tmp/tmpq_x39etg/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpq_x39etg/tokenizer_config.json
# Special tokens file saved in /tmp/tmpq_x39etg/special_tokens_map.json
# added tokens file saved in /tmp/tmpq_x39etg/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    3d926ba..b11c827  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-7500
# Configuration saved in ../models/whisper-base-ta/checkpoint-7500/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-7500/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-7500/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-7500/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-7500/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Saving model checkpoint to /tmp/tmp4ez4g2hn
# Configuration saved in /tmp/tmp4ez4g2hn/config.json
# Model weights saved in /tmp/tmp4ez4g2hn/pytorch_model.bin
# Feature extractor saved in /tmp/tmp4ez4g2hn/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp4ez4g2hn/tokenizer_config.json
# Special tokens file saved in /tmp/tmp4ez4g2hn/special_tokens_map.json
# added tokens file saved in /tmp/tmp4ez4g2hn/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    b11c827..269d4e5  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-8000
# Configuration saved in ../models/whisper-base-ta/checkpoint-8000/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-8000/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-8000/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-8000/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-8000/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Deleting older checkpoint [../models/whisper-base-ta/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpfjwj0n8t
# Configuration saved in /tmp/tmpfjwj0n8t/config.json
# Model weights saved in /tmp/tmpfjwj0n8t/pytorch_model.bin
# Feature extractor saved in /tmp/tmpfjwj0n8t/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpfjwj0n8t/tokenizer_config.json
# Special tokens file saved in /tmp/tmpfjwj0n8t/special_tokens_map.json
# added tokens file saved in /tmp/tmpfjwj0n8t/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    269d4e5..da5fd9e  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-8500
# Configuration saved in ../models/whisper-base-ta/checkpoint-8500/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-8500/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-8500/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-8500/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-8500/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Deleting older checkpoint [../models/whisper-base-ta/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmpe39bv6te
# Configuration saved in /tmp/tmpe39bv6te/config.json
# Model weights saved in /tmp/tmpe39bv6te/pytorch_model.bin
# Feature extractor saved in /tmp/tmpe39bv6te/preprocessor_config.json
# tokenizer config file saved in /tmp/tmpe39bv6te/tokenizer_config.json
# Special tokens file saved in /tmp/tmpe39bv6te/special_tokens_map.json
# added tokens file saved in /tmp/tmpe39bv6te/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    da5fd9e..ccbc184  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-9000
# Configuration saved in ../models/whisper-base-ta/checkpoint-9000/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-9000/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-9000/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-9000/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-9000/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Deleting older checkpoint [../models/whisper-base-ta/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmph3xnuoja
# Configuration saved in /tmp/tmph3xnuoja/config.json
# Model weights saved in /tmp/tmph3xnuoja/pytorch_model.bin
# Feature extractor saved in /tmp/tmph3xnuoja/preprocessor_config.json
# tokenizer config file saved in /tmp/tmph3xnuoja/tokenizer_config.json
# Special tokens file saved in /tmp/tmph3xnuoja/special_tokens_map.json
# added tokens file saved in /tmp/tmph3xnuoja/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    ccbc184..a8d36e8  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-9500
# Configuration saved in ../models/whisper-base-ta/checkpoint-9500/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-9500/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-9500/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-9500/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-9500/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Deleting older checkpoint [../models/whisper-base-ta/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmp49jkbf_9
# Configuration saved in /tmp/tmp49jkbf_9/config.json
# Model weights saved in /tmp/tmp49jkbf_9/pytorch_model.bin
# Feature extractor saved in /tmp/tmp49jkbf_9/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp49jkbf_9/tokenizer_config.json
# Special tokens file saved in /tmp/tmp49jkbf_9/special_tokens_map.json
# added tokens file saved in /tmp/tmp49jkbf_9/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    a8d36e8..1c3389a  main -> main
#
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# Saving model checkpoint to ../models/whisper-base-ta/checkpoint-10000
# Configuration saved in ../models/whisper-base-ta/checkpoint-10000/config.json
# Model weights saved in ../models/whisper-base-ta/checkpoint-10000/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/checkpoint-10000/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/checkpoint-10000/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/checkpoint-10000/added_tokens.json
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Deleting older checkpoint [../models/whisper-base-ta/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to /tmp/tmp_s0z3k4h
# Configuration saved in /tmp/tmp_s0z3k4h/config.json
# Model weights saved in /tmp/tmp_s0z3k4h/pytorch_model.bin
# Feature extractor saved in /tmp/tmp_s0z3k4h/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp_s0z3k4h/tokenizer_config.json
# Special tokens file saved in /tmp/tmp_s0z3k4h/special_tokens_map.json
# added tokens file saved in /tmp/tmp_s0z3k4h/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/parambharat/whisper-base-ta
#    1c3389a..fa8ca2a  main -> main
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/whisper-base-ta/checkpoint-10000 (score: 21.72430589381393).
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# /home/ubuntu/whisper-finetuning/notebooks/../models/whisper-base-ta is already a clone of https://huggingface.co/parambharat/whisper-base-ta. Make sure you pull the latest changes with `repo.git_pull()`.
# max_steps is given, it will override any value given in num_train_epochs
# Using cuda_amp half precision backend
# Saving model checkpoint to /tmp/tmp238sfmlq
# Configuration saved in /tmp/tmp238sfmlq/config.json
# Model weights saved in /tmp/tmp238sfmlq/pytorch_model.bin
# Feature extractor saved in /tmp/tmp238sfmlq/preprocessor_config.json
# tokenizer config file saved in /tmp/tmp238sfmlq/tokenizer_config.json
# Special tokens file saved in /tmp/tmp238sfmlq/special_tokens_map.json
# added tokens file saved in /tmp/tmp238sfmlq/added_tokens.json
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}}
# To https://huggingface.co/parambharat/whisper-base-ta
#    fa8ca2a..e48b35d  main -> main
# TrainOutput(global_step=10000, training_loss=0.09611414756774903, metrics={'train_runtime': 48389.7135, 'train_samples_per_second': 13.226, 'train_steps_per_second': 0.207, 'total_flos': 4.15103975424e+19, 'train_loss': 0.09611414756774903, 'epoch': 0.4})

# %%
from datasets import concatenate_datasets
from multiprocessing import cpu_count

def load_test_dataset():
    fleurs_test = load_dataset("google/fleurs", "ta_in", split="test", use_auth_token=True) 
    fleurs_test = fleurs_test.rename_column("transcription", "sentence")
    fleurs_test = fleurs_test.remove_columns(
        [col for col in fleurs_test.column_names if col not in ["audio", "sentence"]]).cast_column("audio", Audio(sampling_rate=160000))
    common_voice_test = load_dataset("mozilla-foundation/common_voice_11_0", "ta", split="test", use_auth_token=True)
    common_voice_test = common_voice_test.remove_columns(
        [col for col in common_voice_test.column_names if col not in ["audio", "sentence"]]).cast_column("audio", Audio(sampling_rate=160000))
    test_dataset = concatenate_datasets([fleurs_test, common_voice_test])
    test_dataset
    test_dataset = test_dataset.map(prepare_dataset, num_proc=8).with_format("torch")
    return test_dataset


def load_test_dataset():
    fleurs_test = load_dataset("google/fleurs", "ta_in", split="test", use_auth_token=True, streaming=True) 
    fleurs_test = fleurs_test.rename_column("transcription", "sentence")
    fleurs_test = fleurs_test.remove_columns(
        [col for col in fleurs_test.features.keys() if col not in ["audio", "sentence"]]).cast_column("audio", Audio(sampling_rate=160000))
    common_voice_test = load_dataset("mozilla-foundation/common_voice_11_0", "ta", split="test", use_auth_token=True, streaming=True)
    common_voice_test = common_voice_test.remove_columns(
        [col for col in common_voice_test.features.keys() if col not in ["audio", "sentence"]]).cast_column("audio", Audio(sampling_rate=160000))
    test_dataset = concatenate_datasets([fleurs_test, common_voice_test])
    test_dataset
    test_dataset = test_dataset.map(prepare_dataset).with_format("torch")
    return test_dataset

# %%
from datasets import concatenate_datasets
from multiprocessing import cpu_count
def load_test_dataset(config = "fleurs"):
    if config == "fleurs":
        fleurs_test = load_dataset("google/fleurs", "ta_in", split="test", use_auth_token=True, streaming=True) 
        fleurs_test = fleurs_test.rename_column("transcription", "sentence")
        fleurs_test = fleurs_test.remove_columns(
            [col for col in fleurs_test.features.keys() if col not in ["audio", "sentence"]])
        fleurs_test = fleurs_test.cast_column("audio", Audio(sampling_rate=160000))
        test_dataset = fleurs_test.map(prepare_dataset,).with_format("torch")
        return test_dataset
    else:
        
        common_voice_test = load_dataset("mozilla-foundation/common_voice_11_0", "ta", split="test", use_auth_token=True, streaming=True)
        common_voice_test = common_voice_test.remove_columns(
            [col for col in common_voice_test.features.keys() if col not in ["audio", "sentence"]]).cast_column("audio", Audio(sampling_rate=160000))
        common_voice_test = common_voice_test.cast_column("audio", Audio(sampling_rate=160000))
        test_dataset = common_voice_test.map(prepare_dataset,).with_format("torch")
    return common_voice_test
#     test_dataset = concatenate_datasets([fleurs_test, common_voice_test])

# %%
test_dataset = load_test_dataset()

# %%
trainer.evaluate(test_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples: Unknown
#   Batch size = 32
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 32
# {'eval_loss': 1.8921992778778076,
#  'eval_wer': 100.30248033877798,
#  'eval_runtime': 3323.6424,
#  'eval_samples_per_second': 0.178,
#  'eval_steps_per_second': 0.006,
#  'epoch': 0.4}

# %%
kwargs = {
    "language": "ta",
    "model_name": "Whisper Base Ta - Bharat Ramanathan",  # a 'pretty' name for your model
    "finetuned_from": "openai/whisper-base",
    "tasks": "automatic-speech-recognition",
    "tags": "whisper-event",
}

# %%
trainer.push_to_hub(**kwargs)
# Out:
# Saving model checkpoint to ../models/whisper-base-ta
# Configuration saved in ../models/whisper-base-ta/config.json
# Model weights saved in ../models/whisper-base-ta/pytorch_model.bin
# Feature extractor saved in ../models/whisper-base-ta/preprocessor_config.json
# tokenizer config file saved in ../models/whisper-base-ta/tokenizer_config.json
# Special tokens file saved in ../models/whisper-base-ta/special_tokens_map.json
# added tokens file saved in ../models/whisper-base-ta/added_tokens.json
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}, 'metrics': [{'name': 'Wer', 'type': 'wer', 'value': 21.72430589381393}]}
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# To https://huggingface.co/parambharat/whisper-base-ta
#    e48b35d..af77119  main -> main

# %%
wandb.finish()
